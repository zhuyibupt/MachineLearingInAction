# %%
import KNN
import numpy as np

# %%
testVect = KNN.img2vector("digits/testDigits/1_22.txt")
testVect
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %%
KNN.handWritingClass(3) #参数代表最终选取多少个临近邻居
# Out:
# the result is 4 meanwhile the real number is 4
# the result is 4 meanwhile the real number is 4
# the result is 3 meanwhile the real number is 3
# the result is 9 meanwhile the real number is 9
# the result is 0 meanwhile the real number is 0
# the result is 0 meanwhile the real number is 0
# the result is 9 meanwhile the real number is 9
# the result is 7 meanwhile the real number is 7
# the result is 7 meanwhile the real number is 7
# the result is 0 meanwhile the real number is 0
# the result is 3 meanwhile the real number is 3
# the result is 2 meanwhile the real number is 2
# the result is 2 meanwhile the real number is 2
# the result is 5 meanwhile the real number is 5
# the result is 5 meanwhile the real number is 5
# the result is 5 meanwhile the real number is 5
# the result is 2 meanwhile the real number is 2
# the result is 6 meanwhile the real number is 6
# the result is 6 meanwhile the real number is 6
# the result is 9 meanwhile the real number is 9
# ...

# %%
KNN.handWritingClass(5) #参数代表最终选取多少个临近邻居
# Out:
# the result is 4 meanwhile the real number is 4
# the result is 4 meanwhile the real number is 4
# the result is 3 meanwhile the real number is 3
# the result is 9 meanwhile the real number is 9
# the result is 0 meanwhile the real number is 0
# the result is 0 meanwhile the real number is 0
# the result is 9 meanwhile the real number is 9
# the result is 7 meanwhile the real number is 7
# the result is 7 meanwhile the real number is 7
# the result is 0 meanwhile the real number is 0
# the result is 3 meanwhile the real number is 3
# the result is 2 meanwhile the real number is 2
# the result is 2 meanwhile the real number is 2
# the result is 5 meanwhile the real number is 5
# the result is 5 meanwhile the real number is 5
# the result is 5 meanwhile the real number is 5
# the result is 2 meanwhile the real number is 2
# the result is 6 meanwhile the real number is 6
# the result is 6 meanwhile the real number is 6
# the result is 9 meanwhile the real number is 9
# ...
